# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Zulkarnain Yawar\OneDrive\Desktop\SQL-Data-Analysis-Project-3\Dataset\Cleaned_Data_project_1.csv")
df.head()
# Out:
#     order_id        date customer_id  product  quantity  unit_price  \
# 0  ORD200000  2023-01-04      C72649  Monitor         5      570.62
# 1  ORD200001  2024-08-23      C75739    Phone         2      151.35
# 2  ORD200002  2024-02-27      C81728   Tablet         5      550.68
# 3  ORD200003  2023-10-15      C33540    Chair         1      273.19
# 4  ORD200004  2025-05-08      C81840  Printer         4      626.01
#
#   shipping_address payment_method order_status tracking_number  items_in_cart  \
# 0      928 Main St     Debit Card      Shipped     TRK37947903              7
# 1      823 Main St         Online      Shipped     TRK91186779              3
# 2      512 Main St    Credit Card    Cancelled     TRK42903982              8
# 3      275 Main St     Debit Card     Returned     TRK62788070              5
# 4      668 Main St         Online    Delivered     TRK29241424              8
#
#   coupon_code referral_source  total_price
# 0      SAVE10       Instagram      2853.10
# ...

# %%
# !pip install pandas openpyxl sqlalchemy pymysql
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:MyNewPassword123!@localhost/project3"
)

# %%
df.to_sql(
    "orders",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 1200

# %%
pd.read_sql(
    "SELECT * FROM orders LIMIT 5",
    engine
)
# Out:
#     order_id        date customer_id  product  quantity  unit_price  \
# 0  ORD200000  2023-01-04      C72649  Monitor         5      570.62
# 1  ORD200001  2024-08-23      C75739    Phone         2      151.35
# 2  ORD200002  2024-02-27      C81728   Tablet         5      550.68
# 3  ORD200003  2023-10-15      C33540    Chair         1      273.19
# 4  ORD200004  2025-05-08      C81840  Printer         4      626.01
#
#   shipping_address payment_method order_status tracking_number  items_in_cart  \
# 0      928 Main St     Debit Card      Shipped     TRK37947903              7
# 1      823 Main St         Online      Shipped     TRK91186779              3
# 2      512 Main St    Credit Card    Cancelled     TRK42903982              8
# 3      275 Main St     Debit Card     Returned     TRK62788070              5
# 4      668 Main St         Online    Delivered     TRK29241424              8
#
#   coupon_code referral_source  total_price
# 0      SAVE10       Instagram      2853.10
# ...
